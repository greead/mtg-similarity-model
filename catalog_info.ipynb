# %%
import pandas as pd
import json

# %%
with open("catalog.json") as file:
    js = json.load(file)
js
# Out:
# {'supertypes': ['Basic',
#   'Elite',
#   'Legendary',
#   'Ongoing',
#   'Snow',
#   'Token',
#   'World'],
#  'card_types': ['Artifact',
#   'Battle',
#   'Conspiracy',
#   'Creature',
#   'Dungeon',
#   'Emblem',
#   'Enchantment',
#   'Hero',
#   'Instant',
#   'Kindred',
#   'Land',
#   'Phenomenon',
#   'Plane',
#   'Planeswalker',
#   'Scheme',
#   'Sorcery',
#   'Vanguard'],
#  'subtypes': {'artifact_types': ['Attraction',
#    'Blood',
#    'Clue',
#    'Contraption',
#    'Equipment',
#    'Food',
#    'Fortification',
#    'Gold',
#    'Powerstone',
#    'Treasure',
#    'Vehicle'],
#   'battle_types': ['Siege'],
#   'creature_types': ['Advisor',
#    'Aetherborn',
#    'Alien',
#    'Ally',
#    'Angel',
#    'Antelope',
#    'Ape',
#    'Archer',
#    'Archon',
#    'Armadillo',
#    'Army',
#    'Artificer',
#    'Assassin',
#    'Assembly-Worker',
#    'Astartes',
#    'Atog',
#    'Aurochs',
#    'Automaton',
#    'Avatar',
#    'Azra',
#    'Badger',
#    'Balloon',
# ...

# %%
big_set = set()
for subtype, values in js["subtypes"].items():
    vs = set(values)
    print(big_set.isdisjoint(vs))
    big_set = big_set.union(vs)
# Out:
# True
# True
# True
# True
# True
# True
# True
