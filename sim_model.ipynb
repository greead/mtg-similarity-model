# %%
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.decomposition import PCA

# %%
cardbase_filename = "cardbase.json"

# %%
df = pd.read_json(cardbase_filename)

# %%
pd.set_option('display.max_columns', None)

# %%
df.columns
# Out:
# Index(['object', 'id', 'oracle_id', 'multiverse_ids', 'mtgo_id',
#        'mtgo_foil_id', 'tcgplayer_id', 'cardmarket_id', 'name', 'lang',
#        'released_at', 'uri', 'scryfall_uri', 'layout', 'highres_image',
#        'image_status', 'image_uris', 'mana_cost', 'cmc', 'type_line',
#        'oracle_text', 'colors', 'color_identity', 'keywords', 'legalities',
#        'games', 'reserved', 'foil', 'nonfoil', 'finishes', 'oversized',
#        'promo', 'reprint', 'variation', 'set_id', 'set', 'set_name',
#        'set_type', 'set_uri', 'set_search_uri', 'scryfall_set_uri',
#        'rulings_uri', 'prints_search_uri', 'collector_number', 'digital',
#        'rarity', 'flavor_text', 'card_back_id', 'artist', 'artist_ids',
#        'illustration_id', 'border_color', 'frame', 'full_art', 'textless',
#        'booster', 'story_spotlight', 'edhrec_rank', 'prices', 'related_uris',
#        'purchase_uris', 'security_stamp', 'preview', 'power', 'toughness',
#        'penny_rank', 'arena_id', 'promo_types', 'all_parts', 'frame_effects',
#        'produced_mana', 'watermark', 'card_faces', 'tcgplayer_etched_id',
#        'loyalty', 'life_modifier', 'hand_modifier', 'attraction_lights',
#        'color_indicator', 'content_warning'],
#       dtype='object')

# %%
df.head()
# Out:
#   object                                    id  \
# 0   card  86bf43b1-8d4e-4759-bb2d-0b2e03ba7012
# 1   card  7050735c-b232-47a6-a342-01795bfd0d46
# 2   card  e718b21b-46d1-4844-985c-52745657b1ac
# 3   card  036ef8c9-72ac-46ce-af07-83b79d736538
# 4   card  6010d06b-33b6-4631-9b3f-192d8c6b96e7
#
#                               oracle_id multiverse_ids  mtgo_id  mtgo_foil_id  \
# 0  0004ebd0-dfd6-4276-b4a6-de0003e94237        [15862]  15870.0       15871.0
# 1  0006faf6-7a61-426c-9034-579f2cfcfa83       [370780]  49283.0       49284.0
# 2  0007c283-5b7a-4c00-9ca1-b455c8dff8c3       [470580]  77122.0           NaN
# 3  000d5588-5a4c-434e-988d-396632ade42c        [83282]  22609.0       22610.0
# 4  000d8291-d6a8-436e-9e17-7531333686a8             []      NaN           NaN
#
#    tcgplayer_id  cardmarket_id                 name lang  ... produced_mana  \
# 0        3094.0         3081.0           Static Orb   en  ...           NaN
# 1       69965.0       262945.0  Sensory Deprivation   en  ...           NaN
# 2      196536.0       391692.0       Road of Return   en  ...           NaN
# 3       12835.0        12551.0           Storm Crow   en  ...           NaN
# 4           NaN            NaN     Snarlfang Vermin   en  ...           NaN
#
#   watermark card_faces tcgplayer_etched_id  loyalty life_modifier  \
# 0       NaN        NaN                 NaN      NaN           NaN
# 1       NaN        NaN                 NaN      NaN           NaN
# 2       NaN        NaN                 NaN      NaN           NaN
# 3       NaN        NaN                 NaN      NaN           NaN
# 4       NaN        NaN                 NaN      NaN           NaN
#
#   hand_modifier attraction_lights  color_indicator content_warning
# 0           NaN               NaN              NaN             NaN
# 1           NaN               NaN              NaN             NaN
# 2           NaN               NaN              NaN             NaN
# 3           NaN               NaN              NaN             NaN
# 4           NaN               NaN              NaN             NaN
#
# [5 rows x 80 columns]

# %%
df.drop(["object", "oracle_id", "multiverse_ids", "mtgo_id", "mtgo_foil_id", "tcgplayer_id", "cardmarket_id", "lang", "released_at", "uri", "highres_image", "image_status", "reserved", "foil", "nonfoil", "finishes", "oversized", "promo", "reprint", "variation", "set_id", "set_type", "set_uri", "set_search_uri", "scryfall_set_uri", "rulings_uri", "prints_search_uri", "collector_number", "flavor_text", "artist", "artist_ids", "illustration_id", "border_color", "frame", "full_art", "textless", "booster", "story_spotlight", "purchase_uris", "security_stamp", "preview", "penny_rank", "arena_id", "promo_types", "frame_effects", "watermark", "tcgplayer_etched_id"], axis=1, inplace=True)

# %%
df = df.explode("games")
df.reset_index(inplace=True)
df.drop(columns=["index"], inplace=True)

# %%
df.drop(df[~(df["games"] == "paper")].index, inplace=True)

# %%
df.reset_index(inplace=True)
df.drop(columns=["index"], inplace=True)

# %%
df.drop(columns=["games"], inplace=True)

# %%
df.drop(df[~(pd.json_normalize(df["legalities"])["commander"] == "legal")].index, inplace=True)

# %%
df.reset_index(inplace=True)
df.drop(columns=["index"], inplace=True)

# %%
df.drop(columns="legalities", inplace=True)

# %%
# pd.set_option('display.max_colwidth', None)
df[df["content_warning"] == 1.0]
# Out:
# Empty DataFrame
# Columns: [id, name, scryfall_uri, layout, image_uris, mana_cost, cmc, type_line, oracle_text, colors, color_identity, keywords, set, set_name, digital, rarity, card_back_id, edhrec_rank, prices, related_uris, power, toughness, all_parts, produced_mana, card_faces, loyalty, life_modifier, hand_modifier, attraction_lights, color_indicator, content_warning]
# Index: []
#
# [0 rows x 31 columns]

# %%
df[~df["card_faces"].isna()]
# Out:
#                                          id  \
# 273    0dbaef61-fa39-4ea7-bc21-445401c373e7
# 306    e8a51d2a-1582-4bad-995c-e7fe9f810149
# 368    62061e7c-cf19-4f03-b8fa-2bdba62d6b0b
# 408    b0bd107d-3915-4177-aa02-9106f3abbd86
# 447    66724f4e-59dd-4c70-b09b-49947320e6d1
# ...                                     ...
# 26103  228e551e-023a-4c9a-8f32-58dae6ffdf7f
# 26174  d4054ae6-0227-4d99-8cb5-72e8b5d0b726
# 26183  0d200f98-3377-46a3-9197-3cbd95d03dbf
# 26195  56b0f66b-dca9-4a01-9394-20a513c2b225
# 26200  22a6a5f1-1405-4efb-af3e-e1f58d664e99
#
#                                                   name  \
# 273         Ulvenwald Captive // Ulvenwald Abomination
# 306    Azusa's Many Journeys // Likeness of the Seeker
# 368            Witch Enchanter // Witch-Blessed Meadow
# 408                                    Heaven // Earth
# 447                               Breaking // Entering
# ...                                                ...
# 26103          Valakut Awakening // Valakut Stoneforge
# 26174           Vengeful Strangler // Strangling Grasp
# 26183                 Harvest Hand // Scrounged Scythe
# 26195                 Young Blue Dragon // Sand Augury
# 26200           Toralf, God of Fury // Toralf's Hammer
#
#                                             scryfall_uri     layout  \
# 273    https://scryfall.com/card/emn/175/ulvenwald-ca...  transform
# 306    https://scryfall.com/card/neo/172/azusas-many-...  transform
# 368    https://scryfall.com/card/mh3/239/witch-enchan...  modal_dfc
# 408    https://scryfall.com/card/otc/230/heaven-earth...      split
# 447    https://scryfall.com/card/dgm/124/breaking-ent...      split
# ...                                                  ...        ...
# 26103  https://scryfall.com/card/znr/174/valakut-awak...  modal_dfc
# 26174  https://scryfall.com/card/mid/126/vengeful-str...  transform
# 26183  https://scryfall.com/card/soi/256/harvest-hand...  transform
# 26195  https://scryfall.com/card/clb/106/young-blue-d...  adventure
# 26200  https://scryfall.com/card/khm/154/toralf-god-o...  modal_dfc
#
#                                               image_uris            mana_cost  \
# 273                                                  NaN                  NaN
# 306                                                  NaN                  NaN
# 368                                                  NaN                  NaN
# 408    {'small': 'https://cards.scryfall.io/small/fro...  {X}{G} // {X}{R}{R}
# 447    {'small': 'https://cards.scryfall.io/small/fro...  {U}{B} // {4}{B}{R}
# ...                                                  ...                  ...
# 26103                                                NaN                  NaN
# 26174                                                NaN                  NaN
# 26183                                                NaN                  NaN
# 26195  {'small': 'https://cards.scryfall.io/small/fro...     {4}{U} // {1}{U}
# 26200                                                NaN                  NaN
#
#        cmc                                          type_line oracle_text  \
# 273    2.0  Creature — Werewolf Horror // Creature — Eldra...         NaN
# 306    2.0  Enchantment — Saga // Enchantment Creature — H...         NaN
# 368    4.0                   Creature — Human Warlock // Land         NaN
# 408    3.0                                 Instant // Sorcery         NaN
# 447    8.0                                 Sorcery // Sorcery         NaN
# ...    ...                                                ...         ...
# 26103  3.0                                    Instant // Land         NaN
# 26174  2.0       Creature — Human Rogue // Enchantment — Aura         NaN
# 26183  3.0  Artifact Creature — Scarecrow // Artifact — Eq...         NaN
# 26195  5.0           Creature — Dragon // Sorcery — Adventure         NaN
# 26200  4.0  Legendary Creature — God // Legendary Artifact...         NaN
#
#           colors  ... toughness  \
# 273          NaN  ...       NaN
# 306          NaN  ...       NaN
# 368          NaN  ...       NaN
# 408       [G, R]  ...       NaN
# 447    [B, R, U]  ...       NaN
# ...          ...  ...       ...
# 26103        NaN  ...       NaN
# 26174        NaN  ...       NaN
# 26183        NaN  ...       NaN
# 26195        [U]  ...         3
# 26200        NaN  ...       NaN
#
#                                                all_parts produced_mana  \
# 273    [{'object': 'related_card', 'id': '0dbaef61-fa...        [C, G]
# 306                                                  NaN           NaN
# 368                                                  NaN           [W]
# 408                                                  NaN           NaN
# 447                                                  NaN           NaN
# ...                                                  ...           ...
# 26103                                                NaN           [R]
# 26174                                                NaN           NaN
# 26183  [{'object': 'related_card', 'id': '4d323ead-24...           NaN
# 26195  [{'object': 'related_card', 'id': '087c13b7-16...           NaN
# 26200                                                NaN           NaN
#
#                                               card_faces  loyalty  \
# 273    [{'object': 'card_face', 'name': 'Ulvenwald Ca...      NaN
# 306    [{'object': 'card_face', 'name': 'Azusa's Many...      NaN
# 368    [{'object': 'card_face', 'name': 'Witch Enchan...      NaN
# 408    [{'object': 'card_face', 'name': 'Heaven', 'ma...      NaN
# 447    [{'object': 'card_face', 'name': 'Breaking', '...      NaN
# ...                                                  ...      ...
# 26103  [{'object': 'card_face', 'name': 'Valakut Awak...      NaN
# 26174  [{'object': 'card_face', 'name': 'Vengeful Str...      NaN
# 26183  [{'object': 'card_face', 'name': 'Harvest Hand...      NaN
# 26195  [{'object': 'card_face', 'name': 'Young Blue D...      NaN
# 26200  [{'object': 'card_face', 'name': 'Toralf, God ...      NaN
#
#       life_modifier hand_modifier  attraction_lights color_indicator  \
# 273             NaN           NaN                NaN             NaN
# 306             NaN           NaN                NaN             NaN
# 368             NaN           NaN                NaN             NaN
# 408             NaN           NaN                NaN             NaN
# 447             NaN           NaN                NaN             NaN
# ...             ...           ...                ...             ...
# 26103           NaN           NaN                NaN             NaN
# 26174           NaN           NaN                NaN             NaN
# 26183           NaN           NaN                NaN             NaN
# 26195           NaN           NaN                NaN             NaN
# 26200           NaN           NaN                NaN             NaN
#
#       content_warning
# 273               NaN
# 306               NaN
# 368               NaN
# 408               NaN
# 447               NaN
# ...               ...
# 26103             NaN
# 26174             NaN
# 26183             NaN
# 26195             NaN
# 26200             NaN
#
# [661 rows x 31 columns]

# %%
df["life_modifier"].value_counts(dropna=False)
# Out:
# life_modifier
# NaN    26203
# Name: count, dtype: int64

# %%
df["hand_modifier"].value_counts(dropna=False)
# Out:
# hand_modifier
# NaN    26203
# Name: count, dtype: int64

# %%
df["content_warning"].value_counts(dropna=False)
# Out:
# content_warning
# NaN    26203
# Name: count, dtype: int64

# %%
df.drop(columns=["life_modifier", "hand_modifier", "content_warning"], inplace=True)

# %%
df
# Out:
#                                          id  \
# 0      86bf43b1-8d4e-4759-bb2d-0b2e03ba7012
# 1      7050735c-b232-47a6-a342-01795bfd0d46
# 2      e718b21b-46d1-4844-985c-52745657b1ac
# 3      036ef8c9-72ac-46ce-af07-83b79d736538
# 4      b125d1e7-5d9b-4997-88b0-71bdfc19c6f2
# ...                                     ...
# 26198  d6695fa8-881c-407c-91d9-3ac770372d35
# 26199  4d5edf4f-5695-42fc-9e57-c4faef60fbc3
# 26200  22a6a5f1-1405-4efb-af3e-e1f58d664e99
# 26201  09f06f55-7918-46c4-80ff-0bf39e091a4a
# 26202  1ecc983e-bbe3-4bc1-97e9-e40ead987ef0
#
#                                          name  \
# 0                                  Static Orb
# 1                         Sensory Deprivation
# 2                              Road of Return
# 3                                  Storm Crow
# 4                              Walking Sponge
# ...                                       ...
# 26198                        Without Weakness
# 26199                 Firesong and Sunspeaker
# 26200  Toralf, God of Fury // Toralf's Hammer
# 26201                       Samut, the Tested
# 26202                            Sinew Sliver
#
#                                             scryfall_uri     layout  \
# 0      https://scryfall.com/card/7ed/319/static-orb?u...     normal
# 1      https://scryfall.com/card/m14/71/sensory-depri...     normal
# 2      https://scryfall.com/card/c19/34/road-of-retur...     normal
# 3      https://scryfall.com/card/9ed/100/storm-crow?u...     normal
# 4      https://scryfall.com/card/ulg/47/walking-spong...     normal
# ...                                                  ...        ...
# 26198  https://scryfall.com/card/hou/81/without-weakn...     normal
# 26199  https://scryfall.com/card/2x2/215/firesong-and...     normal
# 26200  https://scryfall.com/card/khm/154/toralf-god-o...  modal_dfc
# 26201  https://scryfall.com/card/hou/144/samut-the-te...     normal
# 26202  https://scryfall.com/card/cmm/837/sinew-sliver...     normal
#
#                                               image_uris  mana_cost  cmc  \
# 0      {'small': 'https://cards.scryfall.io/small/fro...        {3}  3.0
# 1      {'small': 'https://cards.scryfall.io/small/fro...        {U}  1.0
# 2      {'small': 'https://cards.scryfall.io/small/fro...     {G}{G}  2.0
# 3      {'small': 'https://cards.scryfall.io/small/fro...     {1}{U}  2.0
# 4      {'small': 'https://cards.scryfall.io/small/fro...     {1}{U}  2.0
# ...                                                  ...        ...  ...
# 26198  {'small': 'https://cards.scryfall.io/small/fro...     {1}{B}  2.0
# 26199  {'small': 'https://cards.scryfall.io/small/fro...  {4}{R}{W}  6.0
# 26200                                                NaN        NaN  4.0
# 26201  {'small': 'https://cards.scryfall.io/small/fro...  {2}{R}{G}  4.0
# 26202  {'small': 'https://cards.scryfall.io/small/fro...     {1}{W}  2.0
#
#                                                type_line  \
# 0                                               Artifact
# 1                                     Enchantment — Aura
# 2                                                Sorcery
# 3                                        Creature — Bird
# 4                                      Creature — Sponge
# ...                                                  ...
# 26198                                            Instant
# 26199               Legendary Creature — Minotaur Cleric
# 26200  Legendary Creature — God // Legendary Artifact...
# 26201                     Legendary Planeswalker — Samut
# 26202                                  Creature — Sliver
#
#                                              oracle_text  colors  ...  \
# 0      As long as Static Orb is untapped, players can...      []  ...
# 1       Enchant creature\nEnchanted creature gets -3/-0.     [U]  ...
# 2      Choose one —\n• Return target permanent card f...     [G]  ...
# 3      Flying (This creature can't be blocked except ...     [U]  ...
# 4      {T}: Target creature loses your choice of flyi...     [U]  ...
# ...                                                  ...     ...  ...
# 26198  Target creature you control gains indestructib...     [B]  ...
# 26199  Red instant and sorcery spells you control hav...  [R, W]  ...
# 26200                                                NaN     NaN  ...
# 26201  +1: Up to one target creature gains double str...  [G, R]  ...
# 26202                    All Sliver creatures get +1/+1.     [W]  ...
#
#                                                   prices  \
# 0      {'usd': '19.41', 'usd_foil': None, 'usd_etched...
# 1      {'usd': '0.04', 'usd_foil': '0.21', 'usd_etche...
# 2      {'usd': '0.41', 'usd_foil': None, 'usd_etched'...
# 3      {'usd': '0.24', 'usd_foil': None, 'usd_etched'...
# 4      {'usd': '0.17', 'usd_foil': '4.91', 'usd_etche...
# ...                                                  ...
# 26198  {'usd': '0.03', 'usd_foil': '0.30', 'usd_etche...
# 26199  {'usd': '0.19', 'usd_foil': '0.24', 'usd_etche...
# 26200  {'usd': '3.75', 'usd_foil': '3.40', 'usd_etche...
# 26201  {'usd': '0.63', 'usd_foil': '1.35', 'usd_etche...
# 26202  {'usd': '0.26', 'usd_foil': None, 'usd_etched'...
#
#                                             related_uris power toughness  \
# 0      {'gatherer': 'https://gatherer.wizards.com/Pag...   NaN       NaN
# 1      {'gatherer': 'https://gatherer.wizards.com/Pag...   NaN       NaN
# 2      {'gatherer': 'https://gatherer.wizards.com/Pag...   NaN       NaN
# 3      {'gatherer': 'https://gatherer.wizards.com/Pag...     1         2
# 4      {'gatherer': 'https://gatherer.wizards.com/Pag...     1         1
# ...                                                  ...   ...       ...
# 26198  {'gatherer': 'https://gatherer.wizards.com/Pag...   NaN       NaN
# 26199  {'gatherer': 'https://gatherer.wizards.com/Pag...     4         6
# 26200  {'gatherer': 'https://gatherer.wizards.com/Pag...   NaN       NaN
# 26201  {'gatherer': 'https://gatherer.wizards.com/Pag...   NaN       NaN
# 26202  {'gatherer': 'https://gatherer.wizards.com/Pag...     1         1
#
#        all_parts produced_mana  \
# 0            NaN           NaN
# 1            NaN           NaN
# 2            NaN           NaN
# 3            NaN           NaN
# 4            NaN           NaN
# ...          ...           ...
# 26198        NaN           NaN
# 26199        NaN           NaN
# 26200        NaN           NaN
# 26201        NaN           NaN
# 26202        NaN           NaN
#
#                                               card_faces  loyalty  \
# 0                                                    NaN      NaN
# 1                                                    NaN      NaN
# 2                                                    NaN      NaN
# 3                                                    NaN      NaN
# 4                                                    NaN      NaN
# ...                                                  ...      ...
# 26198                                                NaN      NaN
# 26199                                                NaN      NaN
# 26200  [{'object': 'card_face', 'name': 'Toralf, God ...      NaN
# 26201                                                NaN        4
# 26202                                                NaN      NaN
#
#       attraction_lights color_indicator
# 0                   NaN             NaN
# 1                   NaN             NaN
# 2                   NaN             NaN
# 3                   NaN             NaN
# 4                   NaN             NaN
# ...                 ...             ...
# 26198               NaN             NaN
# 26199               NaN             NaN
# 26200               NaN             NaN
# 26201               NaN             NaN
# 26202               NaN             NaN
#
# [26203 rows x 28 columns]

# %%
df[~df["color_indicator"].isna()]
# Out:
#                                          id                             name  \
# 1641   01880c6f-be00-48b5-913f-ec6c80ced184                 Resurgent Belief
# 1927   7ee1fcbc-3573-42c5-b3e3-1f44a6400cd0              Glimpse of Tomorrow
# 2195   0186a93c-000a-4b8f-983d-e1471185dc1f                         Evermind
# 2285   c7937e12-76d9-4030-a68c-7a93a3c852cb                    Wheel of Fate
# 3284   d99a9a7d-d9ca-4c11-80ab-e39d5943a315  Asmoranomardicadaistinaculdacar
# 4049   2afc6f7d-ab59-4d64-bd11-6bd0fd4bfcd2                    Profane Tutor
# 4372   a8cca2a2-69e3-4136-936c-7a2774c19351               Crashing Footfalls
# 5784   b1eede29-17a4-437f-a5c2-e24cccbc6a33                       Living End
# 5820   0220c1e9-07bc-44f0-b39e-ca345ec4ea28         Mishra, Lost to Phyrexia
# 6826   414b9230-9d25-4bdf-8b1e-b4fa2035b6a4          Titania, Gaea Incarnate
# 8946   a4fab67f-00c2-4125-9262-d21a29411797          Rograkh, Son of Rohgahh
# 10534  81e00341-030f-433e-b22b-aca42e0a88d2                   Slaughter Pact
# 11957  40a01679-3224-427e-bd1d-b797b0ab68b7               Urza, Planeswalker
# 12229  ee0f88ac-8a90-4057-b0e6-c15fbd02da38                  Summoner's Pact
# 13881  488996b2-06c8-4866-bf0d-4664640c2be1                      Gaea's Will
# 15433  9079c93e-3da8-442a-89d2-609a3eac83b0                 Ancestral Vision
# 16296  bca127ef-349e-4380-875d-49c14fa03b18                Intervention Pact
# 17377  71725895-38cd-4017-bbf0-0b7dc9b5db60              Inevitable Betrayal
# 20639  0febc7fe-4172-4285-9804-a62ce4506c39                  Restore Balance
# 21125  65757321-2f26-44dc-a4f8-31d40fbf1681                     Hypergenesis
# 21140  4612effe-8ca2-4c27-90d2-d9255acc80d9                Pact of the Titan
# 23852  bb3a843b-2dea-4b44-be74-c09c18b9b969                      Dryad Arbor
# 24929  1ed4c0bb-b710-44a1-b8bc-6bd11c27b8b8                 Pact of Negation
#
#                                             scryfall_uri  layout  \
# 1641   https://scryfall.com/card/mh2/26/resurgent-bel...  normal
# 1927   https://scryfall.com/card/mh2/129/glimpse-of-t...  normal
# 2195   https://scryfall.com/card/sok/37/evermind?utm_...  normal
# 2285   https://scryfall.com/card/tsr/198/wheel-of-fat...  normal
# 3284   https://scryfall.com/card/mh2/186/asmoranomard...  normal
# 4049   https://scryfall.com/card/mh2/97/profane-tutor...  normal
# 4372   https://scryfall.com/card/mh1/160/crashing-foo...  normal
# 5784   https://scryfall.com/card/tsr/121/living-end?u...  normal
# 5820   https://scryfall.com/card/bro/163b/mishra-lost...    meld
# 6826   https://scryfall.com/card/bro/256b/titania-gae...    meld
# 8946   https://scryfall.com/card/cmr/197/rograkh-son-...  normal
# 10534  https://scryfall.com/card/tsr/138/slaughter-pa...  normal
# 11957  https://scryfall.com/card/bro/238b/urza-planes...    meld
# 12229  https://scryfall.com/card/tsr/234/summoners-pa...  normal
# 13881  https://scryfall.com/card/mh2/162/gaeas-will?u...  normal
# 15433  https://scryfall.com/card/tsr/52/ancestral-vis...  normal
# 16296  https://scryfall.com/card/fut/8/intervention-p...  normal
# 17377  https://scryfall.com/card/mh2/47/inevitable-be...  normal
# 20639  https://scryfall.com/card/tsr/36/restore-balan...  normal
# 21125  https://scryfall.com/card/tsr/210/hypergenesis...  normal
# 21140  https://scryfall.com/card/tsr/179/pact-of-the-...  normal
# 23852  https://scryfall.com/card/tsr/277/dryad-arbor?...  normal
# 24929  https://scryfall.com/card/tsr/77/pact-of-negat...  normal
#
#                                               image_uris mana_cost  cmc  \
# 1641   {'small': 'https://cards.scryfall.io/small/fro...            0.0
# 1927   {'small': 'https://cards.scryfall.io/small/fro...            0.0
# 2195   {'small': 'https://cards.scryfall.io/small/fro...            0.0
# 2285   {'small': 'https://cards.scryfall.io/small/fro...            0.0
# 3284   {'small': 'https://cards.scryfall.io/small/fro...            0.0
# 4049   {'small': 'https://cards.scryfall.io/small/fro...            0.0
# 4372   {'small': 'https://cards.scryfall.io/small/fro...            0.0
# 5784   {'small': 'https://cards.scryfall.io/small/fro...            0.0
# 5820   {'small': 'https://cards.scryfall.io/small/fro...            7.0
# 6826   {'small': 'https://cards.scryfall.io/small/fro...            3.0
# 8946   {'small': 'https://cards.scryfall.io/small/fro...       {0}  0.0
# 10534  {'small': 'https://cards.scryfall.io/small/fro...       {0}  0.0
# 11957  {'small': 'https://cards.scryfall.io/small/fro...            8.0
# 12229  {'small': 'https://cards.scryfall.io/small/fro...       {0}  0.0
# 13881  {'small': 'https://cards.scryfall.io/small/fro...            0.0
# 15433  {'small': 'https://cards.scryfall.io/small/fro...            0.0
# 16296  {'small': 'https://cards.scryfall.io/small/fro...       {0}  0.0
# 17377  {'small': 'https://cards.scryfall.io/small/fro...            0.0
# 20639  {'small': 'https://cards.scryfall.io/small/fro...            0.0
# 21125  {'small': 'https://cards.scryfall.io/small/fro...            0.0
# 21140  {'small': 'https://cards.scryfall.io/small/fro...       {0}  0.0
# 23852  {'small': 'https://cards.scryfall.io/small/fro...            0.0
# 24929  {'small': 'https://cards.scryfall.io/small/fro...       {0}  0.0
#
#                                                type_line  \
# 1641                                             Sorcery
# 1927                                             Sorcery
# 2195                                    Instant — Arcane
# 2285                                             Sorcery
# 3284                   Legendary Creature — Human Wizard
# 4049                                             Sorcery
# 4372                                             Sorcery
# 5784                                             Sorcery
# 5820   Legendary Artifact Creature — Phyrexian Artificer
# 6826               Legendary Creature — Elemental Avatar
# 8946                 Legendary Creature — Kobold Warrior
# 10534                                            Instant
# 11957                      Legendary Planeswalker — Urza
# 12229                                            Instant
# 13881                                            Sorcery
# 15433                                            Sorcery
# 16296                                            Instant
# 17377                                            Sorcery
# 20639                                            Sorcery
# 21125                                            Sorcery
# 21140                                            Instant
# 23852                       Land Creature — Forest Dryad
# 24929                                            Instant
#
#                                              oracle_text  colors  ...  \
# 1641   Suspend 2—{1}{W} (Rather than cast this card f...     [W]  ...
# 1927   Suspend 3—{R}{R}\nShuffle all permanents you o...     [R]  ...
# 2195   (Nonexistent mana costs can't be paid.)\nDraw ...     [U]  ...
# 2285   Suspend 4—{1}{R} (Rather than cast this card f...     [R]  ...
# 3284   As long as you've discarded a card this turn, ...  [B, R]  ...
# 4049   Suspend 2—{1}{B} (Rather than cast this card f...     [B]  ...
# 4372   Suspend 4—{G} (Rather than cast this card from...     [G]  ...
# 5784   Suspend 3—{2}{B}{B}\nEach player exiles all cr...     [B]  ...
# 5820   Whenever Mishra, Lost to Phyrexia enters the b...  [B, R]  ...
# 6826   Vigilance, reach, trample, haste\nTitania, Gae...     [G]  ...
# 8946   First strike, menace, trample\nPartner (You ca...     [R]  ...
# 10534  Destroy target nonblack creature.\nAt the begi...     [B]  ...
# 11957  You may activate the loyalty abilities of Urza...  [U, W]  ...
# 12229  Search your library for a green creature card,...     [G]  ...
# 13881  Suspend 4—{G}\nUntil end of turn, you may play...     [G]  ...
# 15433  Suspend 4—{U} (Rather than cast this card from...     [U]  ...
# 16296  The next time a source of your choice would de...     [W]  ...
# 17377  Suspend 3—{1}{U}{U} (Rather than cast this car...     [U]  ...
# 20639  Suspend 6—{W}\nEach player chooses a number of...     [W]  ...
# 21125  Suspend 3—{1}{G}{G}\nStarting with you, each p...     [G]  ...
# 21140  Create a 4/4 red Giant creature token.\nAt the...     [R]  ...
# 23852  (Dryad Arbor isn't a spell, it's affected by s...     [G]  ...
# 24929  Counter target spell.\nAt the beginning of you...     [U]  ...
#
#                                                   prices  \
# 1641   {'usd': '0.46', 'usd_foil': '0.68', 'usd_etche...
# 1927   {'usd': '0.13', 'usd_foil': '0.27', 'usd_etche...
# 2195   {'usd': '0.25', 'usd_foil': '1.08', 'usd_etche...
# 2285   {'usd': '2.49', 'usd_foil': '7.18', 'usd_etche...
# 3284   {'usd': '0.20', 'usd_foil': '2.02', 'usd_etche...
# 4049   {'usd': '2.78', 'usd_foil': '3.64', 'usd_etche...
# 4372   {'usd': '0.78', 'usd_foil': '18.17', 'usd_etch...
# 5784   {'usd': '4.07', 'usd_foil': '12.92', 'usd_etch...
# 5820   {'usd': None, 'usd_foil': None, 'usd_etched': ...
# 6826   {'usd': None, 'usd_foil': None, 'usd_etched': ...
# 8946   {'usd': '0.21', 'usd_foil': '3.88', 'usd_etche...
# 10534  {'usd': '0.87', 'usd_foil': '2.63', 'usd_etche...
# 11957  {'usd': None, 'usd_foil': None, 'usd_etched': ...
# 12229  {'usd': '3.86', 'usd_foil': '11.96', 'usd_etch...
# 13881  {'usd': '0.10', 'usd_foil': '0.31', 'usd_etche...
# 15433  {'usd': '4.59', 'usd_foil': '14.83', 'usd_etch...
# 16296  {'usd': '7.19', 'usd_foil': '14.30', 'usd_etch...
# 17377  {'usd': '0.59', 'usd_foil': '1.18', 'usd_etche...
# 20639  {'usd': '0.52', 'usd_foil': '1.99', 'usd_etche...
# 21125  {'usd': '0.77', 'usd_foil': '2.59', 'usd_etche...
# 21140  {'usd': '0.13', 'usd_foil': '0.85', 'usd_etche...
# 23852  {'usd': '4.49', 'usd_foil': '8.37', 'usd_etche...
# 24929  {'usd': '10.54', 'usd_foil': '18.07', 'usd_etc...
#
#                                             related_uris power toughness  \
# 1641   {'gatherer': 'https://gatherer.wizards.com/Pag...   NaN       NaN
# 1927   {'gatherer': 'https://gatherer.wizards.com/Pag...   NaN       NaN
# 2195   {'gatherer': 'https://gatherer.wizards.com/Pag...   NaN       NaN
# 2285   {'gatherer': 'https://gatherer.wizards.com/Pag...   NaN       NaN
# 3284   {'gatherer': 'https://gatherer.wizards.com/Pag...     3         3
# 4049   {'gatherer': 'https://gatherer.wizards.com/Pag...   NaN       NaN
# 4372   {'gatherer': 'https://gatherer.wizards.com/Pag...   NaN       NaN
# 5784   {'gatherer': 'https://gatherer.wizards.com/Pag...   NaN       NaN
# 5820   {'gatherer': 'https://gatherer.wizards.com/Pag...     9         9
# 6826   {'gatherer': 'https://gatherer.wizards.com/Pag...     *         *
# 8946   {'gatherer': 'https://gatherer.wizards.com/Pag...     0         1
# 10534  {'gatherer': 'https://gatherer.wizards.com/Pag...   NaN       NaN
# 11957  {'gatherer': 'https://gatherer.wizards.com/Pag...   NaN       NaN
# 12229  {'gatherer': 'https://gatherer.wizards.com/Pag...   NaN       NaN
# 13881  {'gatherer': 'https://gatherer.wizards.com/Pag...   NaN       NaN
# 15433  {'gatherer': 'https://gatherer.wizards.com/Pag...   NaN       NaN
# 16296  {'gatherer': 'https://gatherer.wizards.com/Pag...   NaN       NaN
# 17377  {'gatherer': 'https://gatherer.wizards.com/Pag...   NaN       NaN
# 20639  {'gatherer': 'https://gatherer.wizards.com/Pag...   NaN       NaN
# 21125  {'gatherer': 'https://gatherer.wizards.com/Pag...   NaN       NaN
# 21140  {'gatherer': 'https://gatherer.wizards.com/Pag...   NaN       NaN
# 23852  {'gatherer': 'https://gatherer.wizards.com/Pag...     1         1
# 24929  {'gatherer': 'https://gatherer.wizards.com/Pag...   NaN       NaN
#
#                                                all_parts produced_mana  \
# 1641                                                 NaN           NaN
# 1927                                                 NaN           NaN
# 2195                                                 NaN           NaN
# 2285                                                 NaN           NaN
# 3284   [{'object': 'related_card', 'id': '2879f780-e1...           NaN
# 4049                                                 NaN           NaN
# 4372   [{'object': 'related_card', 'id': 'a8cca2a2-69...           NaN
# 5784                                                 NaN           NaN
# 5820   [{'object': 'related_card', 'id': 'e2b826be-42...           NaN
# 6826   [{'object': 'related_card', 'id': 'deeb6a21-23...           NaN
# 8946                                                 NaN           NaN
# 10534                                                NaN           NaN
# 11957  [{'object': 'related_card', 'id': '83981313-ff...           NaN
# 12229                                                NaN           NaN
# 13881                                                NaN           NaN
# 15433                                                NaN           NaN
# 16296                                                NaN           NaN
# 17377                                                NaN           NaN
# 20639                                                NaN           NaN
# 21125                                                NaN           NaN
# 21140  [{'object': 'related_card', 'id': '4612effe-8c...           NaN
# 23852                                                NaN           [G]
# 24929                                                NaN           NaN
#
#       card_faces  loyalty attraction_lights color_indicator
# 1641         NaN      NaN               NaN             [W]
# 1927         NaN      NaN               NaN             [R]
# 2195         NaN      NaN               NaN             [U]
# 2285         NaN      NaN               NaN             [R]
# 3284         NaN      NaN               NaN          [B, R]
# 4049         NaN      NaN               NaN             [B]
# 4372         NaN      NaN               NaN             [G]
# 5784         NaN      NaN               NaN             [B]
# 5820         NaN      NaN               NaN          [B, R]
# 6826         NaN      NaN               NaN             [G]
# 8946         NaN      NaN               NaN             [R]
# 10534        NaN      NaN               NaN             [B]
# 11957        NaN        7               NaN          [U, W]
# 12229        NaN      NaN               NaN             [G]
# 13881        NaN      NaN               NaN             [G]
# 15433        NaN      NaN               NaN             [U]
# 16296        NaN      NaN               NaN             [W]
# 17377        NaN      NaN               NaN             [U]
# 20639        NaN      NaN               NaN             [W]
# 21125        NaN      NaN               NaN             [G]
# 21140        NaN      NaN               NaN             [R]
# 23852        NaN      NaN               NaN             [G]
# 24929        NaN      NaN               NaN             [U]
#
# [23 rows x 28 columns]

# %%
df.head()
# Out:
#                                      id                 name  \
# 0  86bf43b1-8d4e-4759-bb2d-0b2e03ba7012           Static Orb
# 1  7050735c-b232-47a6-a342-01795bfd0d46  Sensory Deprivation
# 2  e718b21b-46d1-4844-985c-52745657b1ac       Road of Return
# 3  036ef8c9-72ac-46ce-af07-83b79d736538           Storm Crow
# 4  b125d1e7-5d9b-4997-88b0-71bdfc19c6f2       Walking Sponge
#
#                                         scryfall_uri  layout  \
# 0  https://scryfall.com/card/7ed/319/static-orb?u...  normal
# 1  https://scryfall.com/card/m14/71/sensory-depri...  normal
# 2  https://scryfall.com/card/c19/34/road-of-retur...  normal
# 3  https://scryfall.com/card/9ed/100/storm-crow?u...  normal
# 4  https://scryfall.com/card/ulg/47/walking-spong...  normal
#
#                                           image_uris mana_cost  cmc  \
# 0  {'small': 'https://cards.scryfall.io/small/fro...       {3}  3.0
# 1  {'small': 'https://cards.scryfall.io/small/fro...       {U}  1.0
# 2  {'small': 'https://cards.scryfall.io/small/fro...    {G}{G}  2.0
# 3  {'small': 'https://cards.scryfall.io/small/fro...    {1}{U}  2.0
# 4  {'small': 'https://cards.scryfall.io/small/fro...    {1}{U}  2.0
#
#             type_line                                        oracle_text  \
# 0            Artifact  As long as Static Orb is untapped, players can...
# 1  Enchantment — Aura   Enchant creature\nEnchanted creature gets -3/-0.
# 2             Sorcery  Choose one —\n• Return target permanent card f...
# 3     Creature — Bird  Flying (This creature can't be blocked except ...
# 4   Creature — Sponge  {T}: Target creature loses your choice of flyi...
#
#   colors color_identity   keywords  set         set_name  digital    rarity  \
# 0     []             []         []  7ed  Seventh Edition    False      rare
# 1    [U]            [U]  [Enchant]  m14       Magic 2014    False    common
# 2    [G]            [G]  [Entwine]  c19   Commander 2019    False      rare
# 3    [U]            [U]   [Flying]  9ed    Ninth Edition    False    common
# 4    [U]            [U]         []  ulg    Urza's Legacy    False  uncommon
#
#                            card_back_id  edhrec_rank  \
# 0  0aeebaf5-8c7d-4636-9e82-8c27447861f7       3823.0
# 1  0aeebaf5-8c7d-4636-9e82-8c27447861f7      25614.0
# 2  0aeebaf5-8c7d-4636-9e82-8c27447861f7       6493.0
# 3  0aeebaf5-8c7d-4636-9e82-8c27447861f7      16795.0
# 4  0aeebaf5-8c7d-4636-9e82-8c27447861f7      22854.0
#
#                                               prices  \
# 0  {'usd': '19.41', 'usd_foil': None, 'usd_etched...
# 1  {'usd': '0.04', 'usd_foil': '0.21', 'usd_etche...
# 2  {'usd': '0.41', 'usd_foil': None, 'usd_etched'...
# 3  {'usd': '0.24', 'usd_foil': None, 'usd_etched'...
# 4  {'usd': '0.17', 'usd_foil': '4.91', 'usd_etche...
#
#                                         related_uris power toughness  \
# 0  {'gatherer': 'https://gatherer.wizards.com/Pag...   NaN       NaN
# 1  {'gatherer': 'https://gatherer.wizards.com/Pag...   NaN       NaN
# 2  {'gatherer': 'https://gatherer.wizards.com/Pag...   NaN       NaN
# 3  {'gatherer': 'https://gatherer.wizards.com/Pag...     1         2
# 4  {'gatherer': 'https://gatherer.wizards.com/Pag...     1         1
#
#   all_parts produced_mana card_faces loyalty attraction_lights color_indicator
# 0       NaN           NaN        NaN     NaN               NaN             NaN
# 1       NaN           NaN        NaN     NaN               NaN             NaN
# 2       NaN           NaN        NaN     NaN               NaN             NaN
# 3       NaN           NaN        NaN     NaN               NaN             NaN
# 4       NaN           NaN        NaN     NaN               NaN             NaN

# %%
df["cmc"] = df["cmc"].astype("int64")

# %%
df_dataset = df[df["attraction_lights"].isna()][["id", "name", "mana_cost", "cmc", "type_line", "oracle_text", "colors", "color_identity", "keywords", "set", "rarity", "power", "toughness", "produced_mana", "card_faces", "loyalty"]]

# %%
df_dataset.head()
# Out:
#                                      id                 name mana_cost  cmc  \
# 0  86bf43b1-8d4e-4759-bb2d-0b2e03ba7012           Static Orb       {3}    3
# 1  7050735c-b232-47a6-a342-01795bfd0d46  Sensory Deprivation       {U}    1
# 2  e718b21b-46d1-4844-985c-52745657b1ac       Road of Return    {G}{G}    2
# 3  036ef8c9-72ac-46ce-af07-83b79d736538           Storm Crow    {1}{U}    2
# 4  b125d1e7-5d9b-4997-88b0-71bdfc19c6f2       Walking Sponge    {1}{U}    2
#
#             type_line                                        oracle_text  \
# 0            Artifact  As long as Static Orb is untapped, players can...
# 1  Enchantment — Aura   Enchant creature\nEnchanted creature gets -3/-0.
# 2             Sorcery  Choose one —\n• Return target permanent card f...
# 3     Creature — Bird  Flying (This creature can't be blocked except ...
# 4   Creature — Sponge  {T}: Target creature loses your choice of flyi...
#
#   colors color_identity   keywords  set    rarity power toughness  \
# 0     []             []         []  7ed      rare   NaN       NaN
# 1    [U]            [U]  [Enchant]  m14    common   NaN       NaN
# 2    [G]            [G]  [Entwine]  c19      rare   NaN       NaN
# 3    [U]            [U]   [Flying]  9ed    common     1         2
# 4    [U]            [U]         []  ulg  uncommon     1         1
#
#   produced_mana card_faces loyalty
# 0           NaN        NaN     NaN
# 1           NaN        NaN     NaN
# 2           NaN        NaN     NaN
# 3           NaN        NaN     NaN
# 4           NaN        NaN     NaN

# %%
df_dataset.set_index("id")
# Out:
#                                                                         name  \
# id
# 86bf43b1-8d4e-4759-bb2d-0b2e03ba7012                              Static Orb
# 7050735c-b232-47a6-a342-01795bfd0d46                     Sensory Deprivation
# e718b21b-46d1-4844-985c-52745657b1ac                          Road of Return
# 036ef8c9-72ac-46ce-af07-83b79d736538                              Storm Crow
# b125d1e7-5d9b-4997-88b0-71bdfc19c6f2                          Walking Sponge
# ...                                                                      ...
# d6695fa8-881c-407c-91d9-3ac770372d35                        Without Weakness
# 4d5edf4f-5695-42fc-9e57-c4faef60fbc3                 Firesong and Sunspeaker
# 22a6a5f1-1405-4efb-af3e-e1f58d664e99  Toralf, God of Fury // Toralf's Hammer
# 09f06f55-7918-46c4-80ff-0bf39e091a4a                       Samut, the Tested
# 1ecc983e-bbe3-4bc1-97e9-e40ead987ef0                            Sinew Sliver
#
#                                       mana_cost  cmc  \
# id
# 86bf43b1-8d4e-4759-bb2d-0b2e03ba7012        {3}    3
# 7050735c-b232-47a6-a342-01795bfd0d46        {U}    1
# e718b21b-46d1-4844-985c-52745657b1ac     {G}{G}    2
# 036ef8c9-72ac-46ce-af07-83b79d736538     {1}{U}    2
# b125d1e7-5d9b-4997-88b0-71bdfc19c6f2     {1}{U}    2
# ...                                         ...  ...
# d6695fa8-881c-407c-91d9-3ac770372d35     {1}{B}    2
# 4d5edf4f-5695-42fc-9e57-c4faef60fbc3  {4}{R}{W}    6
# 22a6a5f1-1405-4efb-af3e-e1f58d664e99        NaN    4
# 09f06f55-7918-46c4-80ff-0bf39e091a4a  {2}{R}{G}    4
# 1ecc983e-bbe3-4bc1-97e9-e40ead987ef0     {1}{W}    2
#
#                                                                               type_line  \
# id
# 86bf43b1-8d4e-4759-bb2d-0b2e03ba7012                                           Artifact
# 7050735c-b232-47a6-a342-01795bfd0d46                                 Enchantment — Aura
# e718b21b-46d1-4844-985c-52745657b1ac                                            Sorcery
# 036ef8c9-72ac-46ce-af07-83b79d736538                                    Creature — Bird
# b125d1e7-5d9b-4997-88b0-71bdfc19c6f2                                  Creature — Sponge
# ...                                                                                 ...
# d6695fa8-881c-407c-91d9-3ac770372d35                                            Instant
# 4d5edf4f-5695-42fc-9e57-c4faef60fbc3               Legendary Creature — Minotaur Cleric
# 22a6a5f1-1405-4efb-af3e-e1f58d664e99  Legendary Creature — God // Legendary Artifact...
# 09f06f55-7918-46c4-80ff-0bf39e091a4a                     Legendary Planeswalker — Samut
# 1ecc983e-bbe3-4bc1-97e9-e40ead987ef0                                  Creature — Sliver
#
#                                                                             oracle_text  \
# id
# 86bf43b1-8d4e-4759-bb2d-0b2e03ba7012  As long as Static Orb is untapped, players can...
# 7050735c-b232-47a6-a342-01795bfd0d46   Enchant creature\nEnchanted creature gets -3/-0.
# e718b21b-46d1-4844-985c-52745657b1ac  Choose one —\n• Return target permanent card f...
# 036ef8c9-72ac-46ce-af07-83b79d736538  Flying (This creature can't be blocked except ...
# b125d1e7-5d9b-4997-88b0-71bdfc19c6f2  {T}: Target creature loses your choice of flyi...
# ...                                                                                 ...
# d6695fa8-881c-407c-91d9-3ac770372d35  Target creature you control gains indestructib...
# 4d5edf4f-5695-42fc-9e57-c4faef60fbc3  Red instant and sorcery spells you control hav...
# 22a6a5f1-1405-4efb-af3e-e1f58d664e99                                                NaN
# 09f06f55-7918-46c4-80ff-0bf39e091a4a  +1: Up to one target creature gains double str...
# 1ecc983e-bbe3-4bc1-97e9-e40ead987ef0                    All Sliver creatures get +1/+1.
#
#                                       colors color_identity          keywords  \
# id
# 86bf43b1-8d4e-4759-bb2d-0b2e03ba7012      []             []                []
# 7050735c-b232-47a6-a342-01795bfd0d46     [U]            [U]         [Enchant]
# e718b21b-46d1-4844-985c-52745657b1ac     [G]            [G]         [Entwine]
# 036ef8c9-72ac-46ce-af07-83b79d736538     [U]            [U]          [Flying]
# b125d1e7-5d9b-4997-88b0-71bdfc19c6f2     [U]            [U]                []
# ...                                      ...            ...               ...
# d6695fa8-881c-407c-91d9-3ac770372d35     [B]            [B]         [Cycling]
# 4d5edf4f-5695-42fc-9e57-c4faef60fbc3  [R, W]         [R, W]                []
# 22a6a5f1-1405-4efb-af3e-e1f58d664e99     NaN            [R]  [Trample, Equip]
# 09f06f55-7918-46c4-80ff-0bf39e091a4a  [G, R]         [G, R]                []
# 1ecc983e-bbe3-4bc1-97e9-e40ead987ef0     [W]            [W]                []
#
#                                       set    rarity power toughness  \
# id
# 86bf43b1-8d4e-4759-bb2d-0b2e03ba7012  7ed      rare   NaN       NaN
# 7050735c-b232-47a6-a342-01795bfd0d46  m14    common   NaN       NaN
# e718b21b-46d1-4844-985c-52745657b1ac  c19      rare   NaN       NaN
# 036ef8c9-72ac-46ce-af07-83b79d736538  9ed    common     1         2
# b125d1e7-5d9b-4997-88b0-71bdfc19c6f2  ulg  uncommon     1         1
# ...                                   ...       ...   ...       ...
# d6695fa8-881c-407c-91d9-3ac770372d35  hou    common   NaN       NaN
# 4d5edf4f-5695-42fc-9e57-c4faef60fbc3  2x2      rare     4         6
# 22a6a5f1-1405-4efb-af3e-e1f58d664e99  khm    mythic   NaN       NaN
# 09f06f55-7918-46c4-80ff-0bf39e091a4a  hou    mythic   NaN       NaN
# 1ecc983e-bbe3-4bc1-97e9-e40ead987ef0  cmm    common     1         1
#
#                                      produced_mana  \
# id
# 86bf43b1-8d4e-4759-bb2d-0b2e03ba7012           NaN
# 7050735c-b232-47a6-a342-01795bfd0d46           NaN
# e718b21b-46d1-4844-985c-52745657b1ac           NaN
# 036ef8c9-72ac-46ce-af07-83b79d736538           NaN
# b125d1e7-5d9b-4997-88b0-71bdfc19c6f2           NaN
# ...                                            ...
# d6695fa8-881c-407c-91d9-3ac770372d35           NaN
# 4d5edf4f-5695-42fc-9e57-c4faef60fbc3           NaN
# 22a6a5f1-1405-4efb-af3e-e1f58d664e99           NaN
# 09f06f55-7918-46c4-80ff-0bf39e091a4a           NaN
# 1ecc983e-bbe3-4bc1-97e9-e40ead987ef0           NaN
#
#                                                                              card_faces  \
# id
# 86bf43b1-8d4e-4759-bb2d-0b2e03ba7012                                                NaN
# 7050735c-b232-47a6-a342-01795bfd0d46                                                NaN
# e718b21b-46d1-4844-985c-52745657b1ac                                                NaN
# 036ef8c9-72ac-46ce-af07-83b79d736538                                                NaN
# b125d1e7-5d9b-4997-88b0-71bdfc19c6f2                                                NaN
# ...                                                                                 ...
# d6695fa8-881c-407c-91d9-3ac770372d35                                                NaN
# 4d5edf4f-5695-42fc-9e57-c4faef60fbc3                                                NaN
# 22a6a5f1-1405-4efb-af3e-e1f58d664e99  [{'object': 'card_face', 'name': 'Toralf, God ...
# 09f06f55-7918-46c4-80ff-0bf39e091a4a                                                NaN
# 1ecc983e-bbe3-4bc1-97e9-e40ead987ef0                                                NaN
#
#                                      loyalty
# id
# 86bf43b1-8d4e-4759-bb2d-0b2e03ba7012     NaN
# 7050735c-b232-47a6-a342-01795bfd0d46     NaN
# e718b21b-46d1-4844-985c-52745657b1ac     NaN
# 036ef8c9-72ac-46ce-af07-83b79d736538     NaN
# b125d1e7-5d9b-4997-88b0-71bdfc19c6f2     NaN
# ...                                      ...
# d6695fa8-881c-407c-91d9-3ac770372d35     NaN
# 4d5edf4f-5695-42fc-9e57-c4faef60fbc3     NaN
# 22a6a5f1-1405-4efb-af3e-e1f58d664e99     NaN
# 09f06f55-7918-46c4-80ff-0bf39e091a4a       4
# 1ecc983e-bbe3-4bc1-97e9-e40ead987ef0     NaN
#
# [26181 rows x 15 columns]
